# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gymnasium as gym

ENV = 'CartPole-v1'
NUM_DIGITIZED = 6
GAMMA = 0.99 #decrease rate
Learning_Rate = 0.5 #learning rate
MAX_STEPS = 200 #steps for 1 episode
NUM_EPISODES = 1000 #number of episodes

# %%
class Brain:
    #do Q-learning
    
    def  __init__(self, num_states, num_actions):
        self.num_actions = num_actions #the number of CartPole actions
    
        #create the Q table, row is the discrete state(digitized state^number of variables), column is action(left, right)
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIGITIZED**num_states, num_actions)) #uniform distributed sample with size
    
    def bins(self, clip_min, clip_max, num):
        #convert continous value to discrete value
        return np.linspace(clip_min, clip_max, num + 1)[1: -1]   #num of bins needs num+1 value
    
    def digitize_state(self, observation):
        #get the discrete state in total 1296 states
        cart_pos, cart_v, pole_angle, pole_v = observation
        
        digitized = [
            np.digitize(cart_pos, bins = self.bins(-2.4, 2.4, NUM_DIGITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIGITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.26, 0.26, NUM_DIGITIZED)), #angle represent by radian
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIGITIZED))
        ]
        
        return sum([x* (NUM_DIGITIZED**i) for i, x in enumerate(digitized)])
    
    def update_Q_table(self, observation, action, reward, observation_next):
        state = self.digitize_state(observation)
        state_next = self.digitize_state(observation_next)
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            Learning_Rate * (reward + GAMMA * Max_Q_next - self.q_table[state, action])
        
    def decide_action(self, observation, episode):
        #epsilon-greedy
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)
            
        return action

class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
    
    #update the Q function
    def update_Q_function(self, observation, action, reward, observation_next):
        self.brain.update_Q_table(
            observation, action, reward, observation_next)
     
    #get the action
    def get_action(self, observation, step):
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Environment:
    
    def __init__(self):
        self.env = gym.make(ENV, render_mode="human")#rgb_array_list,rgb_array,human
        num_states = self.env.observation_space.shape[0] #4
        num_actions = self.env.action_space.n #2
        self.agent = Agent(num_states, num_actions) #create the agent
    
    def run(self):
        complete_episodes = 0 #succeed episodes that hold on for more than 195 steps
        is_episode_final = False #last episode flag
        frames = []   #for animation
        
        for episode in range(NUM_EPISODES):   #1000 episodes
            # Resets the environment to an initial internal state, returning an initial observation and info(not use).
            observation,_ = self.env.reset(seed=42)  
            
            for step in range(MAX_STEPS):   #steps in one episode
                
                if is_episode_final is True:  #True / False is singleton in Python, so can use "is" to compare the object, while "==" compares the value
                    frames.append(self.env.render())
                    
                action = self.agent.get_action(observation, episode) #not step
                
                #get state_t+1, reward from action_tobservation, reward, terminated, truncated, info 
                observation_next, _, done, _,_ = self.env.step(action) #reward and info not need
                #if use default reward, use following:
                #observation_next, reward, done, _ = self.env.step(action)   #Test
                #self.agent.update_Q_function(observation, action, reward, observation_next) #Test
                #observation = observation_next #Test
                
                
                #get reward
                if done: #step > 200 or larger than angle
                    if step < 195:
                        reward = -1  #give punishment if game over less than last step
                        complete_episodes = 0  #game over less than 195 step then reset
                    else:   
                        reward = 1  
                        complete_episodes += 1  
                else:
                    reward = 0   #until done, reward is 0 
                
                #update Q table
                self.agent.update_Q_function(observation, action, reward, observation_next)
                
                #update observation
                observation = observation_next
                
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(episode, step + 1))
                    break
                
            if is_episode_final is True:  #save the animation
                # display_frames_as_gif(frames)
                break
                    
            if complete_episodes >= 10:
                print('succeeded for 10 times')
                is_episode_final = True
cp_env=Environment()
# print('Q array size: ',cp_env.agent.brain.q_table.shape)
print('observation space: ',cp_env.env.observation_space)
print('action space: ',cp_env.env.action_space)
# Out:
# observation space:  Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# action space:  Discrete(2)

# %%
# env=Environment()
cp_env.run()
# Out:
# 0 Episode: Finished after 11 time steps
# 1 Episode: Finished after 10 time steps
# 2 Episode: Finished after 10 time steps
# 3 Episode: Finished after 10 time steps
# 4 Episode: Finished after 10 time steps
# 5 Episode: Finished after 10 time steps
# 6 Episode: Finished after 113 time steps
# 7 Episode: Finished after 12 time steps
# 8 Episode: Finished after 13 time steps
# 9 Episode: Finished after 14 time steps
# 10 Episode: Finished after 12 time steps
# 11 Episode: Finished after 12 time steps
# 12 Episode: Finished after 12 time steps
# 13 Episode: Finished after 13 time steps
# 14 Episode: Finished after 14 time steps
# 15 Episode: Finished after 13 time steps
# 16 Episode: Finished after 39 time steps
# 17 Episode: Finished after 13 time steps
# 18 Episode: Finished after 12 time steps
# 19 Episode: Finished after 42 time steps
# 20 Episode: Finished after 12 time steps
# 21 Episode: Finished after 13 time steps
# 22 Episode: Finished after 41 time steps
# 23 Episode: Finished after 75 time steps
# 24 Episode: Finished after 97 time steps
# 25 Episode: Finished after 10 time steps
# 26 Episode: Finished after 10 time steps
# 27 Episode: Finished after 10 time steps
# 28 Episode: Finished after 10 time steps
# 29 Episode: Finished after 99 time steps
# 30 Episode: Finished after 89 time steps
# 31 Episode: Finished after 51 time steps
# 32 Episode: Finished after 121 time steps
# 33 Episode: Finished after 14 time steps
# 34 Episode: Finished after 34 time steps
# 35 Episode: Finished after 16 time steps
# 36 Episode: Finished after 58 time steps
# 37 Episode: Finished after 16 time steps
# 38 Episode: Finished after 22 time steps
# 39 Episode: Finished after 16 time steps
# 40 Episode: Finished after 10 time steps
# 41 Episode: Finished after 10 time steps
# 42 Episode: Finished after 109 time steps
# 43 Episode: Finished after 47 time steps
# 44 Episode: Finished after 42 time steps
# 45 Episode: Finished after 16 time steps
# 46 Episode: Finished after 17 time steps
# 47 Episode: Finished after 42 time steps
# 48 Episode: Finished after 92 time steps
# 49 Episode: Finished after 19 time steps
# 50 Episode: Finished after 16 time steps
# 51 Episode: Finished after 19 time steps
# 52 Episode: Finished after 14 time steps
# 53 Episode: Finished after 13 time steps
# 54 Episode: Finished after 13 time steps
# 55 Episode: Finished after 19 time steps
# 56 Episode: Finished after 30 time steps
# 57 Episode: Finished after 50 time steps
# 59 Episode: Finished after 27 time steps
# 60 Episode: Finished after 55 time steps
# 61 Episode: Finished after 25 time steps
# 62 Episode: Finished after 24 time steps
# 63 Episode: Finished after 25 time steps
# 64 Episode: Finished after 22 time steps
# 65 Episode: Finished after 27 time steps
# 66 Episode: Finished after 26 time steps
# 67 Episode: Finished after 85 time steps
# 68 Episode: Finished after 26 time steps
# 69 Episode: Finished after 16 time steps
# 70 Episode: Finished after 10 time steps
# 71 Episode: Finished after 15 time steps
# 72 Episode: Finished after 23 time steps
# 73 Episode: Finished after 56 time steps
# 74 Episode: Finished after 39 time steps
# 75 Episode: Finished after 56 time steps
# 76 Episode: Finished after 53 time steps
# 77 Episode: Finished after 56 time steps
# 78 Episode: Finished after 56 time steps
# 79 Episode: Finished after 57 time steps
# 80 Episode: Finished after 57 time steps
# 81 Episode: Finished after 79 time steps
# 82 Episode: Finished after 55 time steps
# 83 Episode: Finished after 44 time steps
# 84 Episode: Finished after 58 time steps
# 85 Episode: Finished after 46 time steps
# 86 Episode: Finished after 103 time steps
# 87 Episode: Finished after 58 time steps
# 88 Episode: Finished after 200 time steps
# 89 Episode: Finished after 83 time steps
# 90 Episode: Finished after 80 time steps
# 91 Episode: Finished after 85 time steps
# 92 Episode: Finished after 82 time steps
# 93 Episode: Finished after 15 time steps
# 94 Episode: Finished after 14 time steps
# 95 Episode: Finished after 10 time steps
# 96 Episode: Finished after 10 time steps
# 97 Episode: Finished after 156 time steps
# 98 Episode: Finished after 179 time steps
# 99 Episode: Finished after 101 time steps
# 100 Episode: Finished after 134 time steps
# 106 Episode: Finished after 149 time steps
# 107 Episode: Finished after 161 time steps
# 108 Episode: Finished after 135 time steps
# 109 Episode: Finished after 131 time steps
# 110 Episode: Finished after 193 time steps
# 112 Episode: Finished after 147 time steps
# 113 Episode: Finished after 69 time steps
# 115 Episode: Finished after 122 time steps
# 119 Episode: Finished after 112 time steps
# 120 Episode: Finished after 91 time steps
# 121 Episode: Finished after 66 time steps
# 122 Episode: Finished after 66 time steps
# 123 Episode: Finished after 62 time steps
# 124 Episode: Finished after 88 time steps
# 125 Episode: Finished after 106 time steps
# 126 Episode: Finished after 108 time steps
# 127 Episode: Finished after 75 time steps
# 128 Episode: Finished after 109 time steps
# 129 Episode: Finished after 112 time steps
# 130 Episode: Finished after 115 time steps
# 131 Episode: Finished after 146 time steps
# 132 Episode: Finished after 105 time steps
# 133 Episode: Finished after 119 time steps
# 134 Episode: Finished after 137 time steps
# 135 Episode: Finished after 117 time steps
# 136 Episode: Finished after 117 time steps
# 137 Episode: Finished after 107 time steps
# 138 Episode: Finished after 107 time steps
# 139 Episode: Finished after 111 time steps
# 140 Episode: Finished after 151 time steps
# 141 Episode: Finished after 107 time steps
# 142 Episode: Finished after 167 time steps
# 143 Episode: Finished after 115 time steps
# 144 Episode: Finished after 118 time steps
# 146 Episode: Finished after 107 time steps
# 147 Episode: Finished after 125 time steps
# 148 Episode: Finished after 125 time steps
# 149 Episode: Finished after 106 time steps
# 150 Episode: Finished after 102 time steps
# 151 Episode: Finished after 118 time steps
# 152 Episode: Finished after 170 time steps
# 153 Episode: Finished after 90 time steps
# 154 Episode: Finished after 178 time steps
# 155 Episode: Finished after 96 time steps
# 156 Episode: Finished after 132 time steps
# 157 Episode: Finished after 165 time steps
# 158 Episode: Finished after 63 time steps
# 159 Episode: Finished after 180 time steps
# 160 Episode: Finished after 86 time steps
# 161 Episode: Finished after 98 time steps
# 162 Episode: Finished after 163 time steps
# 164 Episode: Finished after 111 time steps
# 165 Episode: Finished after 107 time steps
# 166 Episode: Finished after 84 time steps
# 167 Episode: Finished after 133 time steps
# 168 Episode: Finished after 100 time steps
# 169 Episode: Finished after 80 time steps
# 170 Episode: Finished after 105 time steps
# 171 Episode: Finished after 140 time steps
# 173 Episode: Finished after 98 time steps
# 174 Episode: Finished after 70 time steps
# 175 Episode: Finished after 49 time steps
# 176 Episode: Finished after 46 time steps
# 177 Episode: Finished after 67 time steps
# 178 Episode: Finished after 47 time steps
# 179 Episode: Finished after 70 time steps
# 180 Episode: Finished after 71 time steps
# 181 Episode: Finished after 68 time steps
# 182 Episode: Finished after 69 time steps
# 183 Episode: Finished after 50 time steps
# 184 Episode: Finished after 48 time steps
# 185 Episode: Finished after 46 time steps
# 186 Episode: Finished after 182 time steps
# 187 Episode: Finished after 104 time steps
# 188 Episode: Finished after 96 time steps
# 189 Episode: Finished after 198 time steps
# 191 Episode: Finished after 129 time steps
# 192 Episode: Finished after 113 time steps
# 193 Episode: Finished after 102 time steps
# 194 Episode: Finished after 80 time steps
# 195 Episode: Finished after 103 time steps
# 197 Episode: Finished after 96 time steps
# 198 Episode: Finished after 88 time steps
# 199 Episode: Finished after 106 time steps
# 200 Episode: Finished after 129 time steps
# 201 Episode: Finished after 98 time steps
# 202 Episode: Finished after 46 time steps
# 203 Episode: Finished after 107 time steps
# 205 Episode: Finished after 46 time steps
# 206 Episode: Finished after 157 time steps
# 207 Episode: Finished after 125 time steps
# 208 Episode: Finished after 52 time steps
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 # env=Environment()
# ----> 2 env.run()
#
# Cell In[26], line 25, in Environment.run(self)
#      22 action = self.agent.get_action(observation, episode) #not step
#      24 #get state_t+1, reward from action_tobservation, reward, terminated, truncated, info
# ---> 25 observation_next, _, done, _,_ = self.env.step(action) #reward and info not need
#      26 #if use default reward, use following:
#      27 #observation_next, reward, done, _ = self.env.step(action)   #Test
#      28 #self.agent.update_Q_function(observation, action, reward, observation_next) #Test
#    (...)
#      31
#      32 #get reward
#      33 if done: #step > 200 or larger than angle
#
# File c:\Users\cwdbo\anaconda3\envs\tr_gym_qlearning\Lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\cwdbo\anaconda3\envs\tr_gym_qlearning\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Users\cwdbo\anaconda3\envs\tr_gym_qlearning\Lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Users\cwdbo\anaconda3\envs\tr_gym_qlearning\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:190, in CartPoleEnv.step(self, action)
#     187     reward = 0.0
#     189 if self.render_mode == "human":
# --> 190     self.render()
#     191 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File c:\Users\cwdbo\anaconda3\envs\tr_gym_qlearning\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
plt.plot(np.arange(1,NUM_EPISODES+1,1),env.Step)
plt.xlabel("The number of episodes")
plt.ylabel("The number of time steps")
plt.show()
Front_average=sum(env.Step[1:int(NUM_EPISODES/2)+1:1])/NUM_EPISODES/2
Back_average=sum(env.Step[int(NUM_EPISODES/2)+1:int(NUM_EPISODES+1):1])/NUM_EPISODES/2
print("The average of the first half time steps is {}",Front_average)
print("The average of the second half time steps is {}",Back_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.plot(np.arange(1,NUM_EPISODES+1,1),step)
#       2 plt.xlabel("The number of episodes")
#       3 plt.ylabel("The number of time steps")
#
# NameError: name 'step' is not defined
